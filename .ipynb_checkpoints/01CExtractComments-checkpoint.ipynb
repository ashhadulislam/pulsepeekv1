# %%
import pandas as pd
import os
import time
import subprocess
import json
from collections import defaultdict

TEMP_DIR = 'scratchpad'
PROCESSED_COMMENTS_DIR = 'processed_comments'
COMMENTS_CSV = f'{PROCESSED_COMMENTS_DIR}/comments.csv'

os.makedirs(TEMP_DIR, exist_ok=True)
os.makedirs(PROCESSED_COMMENTS_DIR, exist_ok=True)

def run_yt_dlp(video_id, max_comments=100):
    filepath = os.path.join(TEMP_DIR, f"{video_id}")
    command = [
        "yt-dlp",
        "--skip-download",
        "--write-comments",
        "--no-warnings",
        "--output", filepath,
        "--extractor-args", f"youtube:max_comments={max_comments}",
        f"https://www.youtube.com/watch?v={video_id}"
    ]
    subprocess.run(command, check=True, text=True)


def parse_comments(video_id):
    with open(os.path.join(TEMP_DIR, f'{video_id}.info.json'), "r", encoding="utf-8") as f:
        data = json.load(f)
    comments = data['comments']
    title = data['title']
    uploader = data['uploader_id']

    comment_dict = {}
    replies = defaultdict(list)
    for c in comments:
        if c.get("parent") and c["parent"] != "root":
            replies[c["parent"]].append({**c, "is_reply": True})
        else:
            comment_dict[c["id"]] = {**c, "replies": [], "is_reply": False}
    for pid, rep in replies.items():
        if pid in comment_dict:
            comment_dict[pid]["replies"] = rep
    return list(comment_dict.values()), title, uploader


def to_process(video_id):
    if not os.path.exists(COMMENTS_CSV):
        return True
    df = pd.read_csv(COMMENTS_CSV)
    return video_id not in df['id'].astype(str).values


# Main loop
df_url_details = pd.read_csv('URLs/url_channel_id.csv')
data_res = []

for video_id in df_url_details.id.astype(str):
    if not to_process(video_id):
        #print(f"⏩ Skipping already processed video ID: {video_id}")
        continue

    try:
        run_yt_dlp(video_id, max_comments=100)
        comments, title, uploader = parse_comments(video_id)

        data_res.append({
            'creator_id': uploader,
            'id': video_id,
            'title': title,
            'timestamp': str(time.time()),
            'comments': json.dumps(comments)
        })

        # Append to CSV immediately to avoid reprocessing on crash
        df = pd.DataFrame(data_res)
        if os.path.exists(COMMENTS_CSV):
            df.to_csv(COMMENTS_CSV, mode='a', index=False, header=False)
        else:
            df.to_csv(COMMENTS_CSV, index=False)
        data_res.clear()

    except Exception as e:
        print(f"❌ Failed to process video ID: {video_id}")
        print(e)
# Out:
# ⏩ Skipping already processed video ID: dua91-ntjgU
# ⏩ Skipping already processed video ID: M88UpaT_iio
# ⏩ Skipping already processed video ID: yn-IiJODZLc
# ⏩ Skipping already processed video ID: cwOPw3fBMs4
# ⏩ Skipping already processed video ID: 6DTys4OCPhs
# ⏩ Skipping already processed video ID: mGjeWrERxPg
# ⏩ Skipping already processed video ID: x55BVjUo77U
# ⏩ Skipping already processed video ID: wvBLz5ViSvs
# ⏩ Skipping already processed video ID: APA0htT-AV0
# ⏩ Skipping already processed video ID: jiLTkhkVwP4
# ⏩ Skipping already processed video ID: dzi66yHoOyA
# ⏩ Skipping already processed video ID: SyB6dj0kkxU
# ⏩ Skipping already processed video ID: yzkkzt595WE
# ⏩ Skipping already processed video ID: FfV434-TN7Q
# ⏩ Skipping already processed video ID: g0QYWoh8hsM
# ⏩ Skipping already processed video ID: 7_5WdJlXKLo
# ⏩ Skipping already processed video ID: pOIEdCZvbrQ
# ⏩ Skipping already processed video ID: -VK7GF3bgnA
# ⏩ Skipping already processed video ID: 0UtHedAXIkA
# ⏩ Skipping already processed video ID: 7tqYgfhCwb4
# ⏩ Skipping already processed video ID: 1suta8hYDxo
# ⏩ Skipping already processed video ID: Ojm4C0qwhMM
# ⏩ Skipping already processed video ID: ItK0890LP-g
# ⏩ Skipping already processed video ID: dIAMoGzeut0
# ⏩ Skipping already processed video ID: feMoy5ioaeU
# ⏩ Skipping already processed video ID: Slx5ZH5NZBM
# ⏩ Skipping already processed video ID: aGkNouIMzFY
# ⏩ Skipping already processed video ID: 4XaMJrS9DvY
# ⏩ Skipping already processed video ID: 6xhUFLlG_58
# ⏩ Skipping already processed video ID: x84vLClrXHw
# ⏩ Skipping already processed video ID: JTcydTXWh6A
# ⏩ Skipping already processed video ID: IsqAu9bt9tI
# ⏩ Skipping already processed video ID: jGSm0wWxhxw
# ⏩ Skipping already processed video ID: NbpK63NPvC0
# ⏩ Skipping already processed video ID: xGwtHZZ00GE
# ⏩ Skipping already processed video ID: fdwsNbbrGbo
# ⏩ Skipping already processed video ID: dYN_7AuX9mc
# ⏩ Skipping already processed video ID: 00NZ6m2oDHs
# ⏩ Skipping already processed video ID: xXjkg4or8d0
# ⏩ Skipping already processed video ID: Tfg53uwQK-Q
# ⏩ Skipping already processed video ID: dRJZqdWHXeA
# ⏩ Skipping already processed video ID: lDBDgMkhZtE
# ⏩ Skipping already processed video ID: mXohKXpZqss
# ⏩ Skipping already processed video ID: 4lth2pImfaE
# ⏩ Skipping already processed video ID: rWsg0NgJjjc
# ⏩ Skipping already processed video ID: TLh2DXk149Q
# ⏩ Skipping already processed video ID: v5sBssBzRcA
# ⏩ Skipping already processed video ID: bWM4zjA2rQ8
# ⏩ Skipping already processed video ID: -tJZffvpSYA
# ⏩ Skipping already processed video ID: JlkaOMU0fqA
# ⏩ Skipping already processed video ID: eLy6EayLUG4
# ⏩ Skipping already processed video ID: dXlSmWppK28
# ⏩ Skipping already processed video ID: spMkR6x3SyU
# ⏩ Skipping already processed video ID: 0TVGXqou4es
# ⏩ Skipping already processed video ID: iQnIHqC0ZyQ
# ⏩ Skipping already processed video ID: tbe4PMj6ht8
# ⏩ Skipping already processed video ID: RljGEIvOUjM
# ⏩ Skipping already processed video ID: Ip9XfNHojiE
# ⏩ Skipping already processed video ID: G2AQeVwuQ_0
# ⏩ Skipping already processed video ID: ulLja3PF_bM
# ⏩ Skipping already processed video ID: IIMLbe7aIqg
# ⏩ Skipping already processed video ID: gjNMEtgHy6I
# ⏩ Skipping already processed video ID: VNj_Dh9qfa4
# ⏩ Skipping already processed video ID: XF7fJdLYEB4
# ⏩ Skipping already processed video ID: 3bf9gONQCnY
# ⏩ Skipping already processed video ID: iIv9etpaF2o
# ⏩ Skipping already processed video ID: o4nynacgFp0
# ⏩ Skipping already processed video ID: 3VzyY0njYPM
# ⏩ Skipping already processed video ID: Q0L4zPg-Wqc
# ⏩ Skipping already processed video ID: XxKxfxkhBYY
# ⏩ Skipping already processed video ID: AZUvUhQ8dtg
# ⏩ Skipping already processed video ID: goagDEHSUz0
# ⏩ Skipping already processed video ID: RUr14I9mHOs
# ⏩ Skipping already processed video ID: 6nw78xnIcy8
# ⏩ Skipping already processed video ID: u90rTQrl7R8
# ⏩ Skipping already processed video ID: I6fbRBiRzpo
# ⏩ Skipping already processed video ID: _56rFqE1xq0
# ⏩ Skipping already processed video ID: vFRohyIIYbg
# ⏩ Skipping already processed video ID: DljT1gkHSDQ
# ⏩ Skipping already processed video ID: YdUZko10qs4
# ⏩ Skipping already processed video ID: ygG3qon_vNs
# ⏩ Skipping already processed video ID: ZEF2PzDvdt8
# ⏩ Skipping already processed video ID: Xgu7wttFOSQ
# ⏩ Skipping already processed video ID: yDD7FWc5_ZU
# ⏩ Skipping already processed video ID: -nIAFBgkM8k
# ⏩ Skipping already processed video ID: 5FgrNqW7afg
# ⏩ Skipping already processed video ID: iWWUsX_qAJ8
# ⏩ Skipping already processed video ID: _KF_KfRDT-s
# ⏩ Skipping already processed video ID: L6FckNMYobM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4rvFm18eyfU
# [youtube] 4rvFm18eyfU: Downloading webpage
# [youtube] 4rvFm18eyfU: Downloading tv client config
# [youtube] 4rvFm18eyfU: Downloading player 79e70f61-main
# [youtube] 4rvFm18eyfU: Downloading tv player API JSON
# [youtube] 4rvFm18eyfU: Downloading ios player API JSON
# [youtube] 4rvFm18eyfU: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [info] 4rvFm18eyfU: Downloading 1 format(s): 616+251
# [info] There are no subtitles for the requested languages
# Deleting existing file scratchpad/4rvFm18eyfU.webp
# [info] Downloading video thumbnail 44 ...
# [info] Writing video thumbnail 44 to: scratchpad/4rvFm18eyfU.webp
# [info] Writing video metadata as JSON to: scratchpad/4rvFm18eyfU.info.json
# ❌ Failed to process video ID: 4rvFm18eyfU
# 'comments'
# ⏩ Skipping already processed video ID: 4NlWZoNI75M
# ⏩ Skipping already processed video ID: YaCIVz9lR64
# ⏩ Skipping already processed video ID: Q-GesbLbYd8
# ⏩ Skipping already processed video ID: GtpJC_cKzkY
# ⏩ Skipping already processed video ID: LL-yXJceuuQ
# ⏩ Skipping already processed video ID: OYTXmT_1rgE
# ⏩ Skipping already processed video ID: KbFoSos-OiY
# ⏩ Skipping already processed video ID: ZpRgaD1nhDI
# ⏩ Skipping already processed video ID: i2Ok6q1v-Js
# ⏩ Skipping already processed video ID: uuYGqnmOT2A
# ⏩ Skipping already processed video ID: B-PrI3bvF3U
# ⏩ Skipping already processed video ID: SL5IidCHRhE
# ⏩ Skipping already processed video ID: EntxTVTKZSo
# ⏩ Skipping already processed video ID: SLV-r2capcY
# ⏩ Skipping already processed video ID: TQ--KlYo0K0
# ⏩ Skipping already processed video ID: zz6L18WrunQ
# ⏩ Skipping already processed video ID: HCpaZMrQv_4
# ⏩ Skipping already processed video ID: LJE2RuT09L8
# ⏩ Skipping already processed video ID: HcWtoJhPVjE
# ⏩ Skipping already processed video ID: m6WCpud9Yug
# ⏩ Skipping already processed video ID: C-0sENuxciQ
# ⏩ Skipping already processed video ID: cgrUbCXDVME
# ⏩ Skipping already processed video ID: ikjwuL-P3j8
# ⏩ Skipping already processed video ID: oYnCyiCbLe8
# ⏩ Skipping already processed video ID: h_fFd_L3VlU
# ⏩ Skipping already processed video ID: LRcjBs4gbPo
# ⏩ Skipping already processed video ID: Qxe0nSisYdU
# ⏩ Skipping already processed video ID: N7wkiXb6ung
# ⏩ Skipping already processed video ID: 3NeQm6-nug0
# ⏩ Skipping already processed video ID: xa3WUI3DxHk
# ⏩ Skipping already processed video ID: GwRiUSp_GKo
# ⏩ Skipping already processed video ID: G8gavsAYn7k
# ⏩ Skipping already processed video ID: 7sTky1itvHA
# ⏩ Skipping already processed video ID: 7U5bO_XewCE
# ⏩ Skipping already processed video ID: GWyNsPNSnJg
# ⏩ Skipping already processed video ID: Wc8W04hI1hE
# ⏩ Skipping already processed video ID: GS6NtUhtCaU
# ⏩ Skipping already processed video ID: ixloCv-BOd0
# ⏩ Skipping already processed video ID: A9Qz5M-0g0E
# ⏩ Skipping already processed video ID: oa-7QypPjEg
# ⏩ Skipping already processed video ID: sXcvky2H15U
# ⏩ Skipping already processed video ID: Wd0JTnUc4Bc
# ⏩ Skipping already processed video ID: ADmAAxPY5gA

# %%
df_test=pd.read_csv(f'{PROCESSED_COMMENTS_DIR}/comments.csv')
df_test['comments'] = df_test['comments'].apply(json.loads)

# %%
df_test.shape

# %%
df_test.tail()

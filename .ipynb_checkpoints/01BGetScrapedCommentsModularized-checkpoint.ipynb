# %%
import os
import re
import json
import time
import pickle
import subprocess
from datetime import datetime
from collections import defaultdict
import pandas as pd
from openai import OpenAI
import hashlib

API_KEY = 'sk-bedceae2ceba437f944db22706354095'


COMMENTS_DIR = "comments_scraped"
CSV_DIR = "comments_scraped_csv"
PKL_DIR = "comments_scraped_pkl"
INSIGHTS_DIR = "insights"
HASH_DIR = "hashes"



def save_latest_youtube_urls(creator_id, num_videos=15, output_dir="URLs"):
    """
    Fetches the latest YouTube video URLs from a given creator's channel
    and appends new ones to the existing file, avoiding duplicates.

    Args:
        creator_id (str): YouTube channel handle (e.g., "@smiletojannah")
        num_videos (int): Number of latest video URLs to fetch
        output_dir (str): Folder to save the CSV file with URLs

    Returns:
        List[str]: List of all URLs saved in the CSV (old + new, unique)
    """
    os.makedirs(output_dir, exist_ok=True)
    channel_url = f"https://www.youtube.com/{creator_id}"
    output_path = os.path.join(output_dir, f"{creator_id.strip('@')}.csv")

    try:
        result = subprocess.run(
            ["yt-dlp", "--dump-json", "--flat-playlist", "--playlist-end", str(num_videos), channel_url],
            capture_output=True, text=True, check=True
        )

        video_entries = [json.loads(line) for line in result.stdout.strip().split('\n')]
        new_urls = [f"https://www.youtube.com/watch?v={entry['id']}" for entry in video_entries]

        # Load existing if available
        if os.path.exists(output_path):
            existing_df = pd.read_csv(output_path)
            all_urls = pd.Series(existing_df['urls'].tolist() + new_urls).drop_duplicates().tolist()
        else:
            all_urls = new_urls

        # Save updated list
        pd.DataFrame({'urls': all_urls}).to_csv(output_path, index=False)
        print(f"✅ Total {len(all_urls)} URLs saved to {output_path}")        

    except subprocess.CalledProcessError as e:
        print(f"❌ Failed to fetch videos for {creator_id}")
        print(e.stderr)
        return []
        

def fetch_latest_youtube_urls(creator_id, dir_="URLs"):
    CHANNEL_URLS = pd.read_csv(f'{dir_}/{creator_id}.csv')['urls']
    return CHANNEL_URLS

def compute_hash(top_comments):
    joined = '\n'.join(top_comments).strip()
    return hashlib.sha256(joined.encode('utf-8')).hexdigest()

def get_saved_hash(video_id):
    path = os.path.join(HASH_DIR, f"{video_id}.hash")
    if os.path.exists(path):
        with open(path, "r") as f:
            return f.read().strip()
    return None

def save_hash(video_id, hash_str):
    with open(os.path.join(HASH_DIR, f"{video_id}.hash"), "w") as f:
        f.write(hash_str)

os.makedirs(COMMENTS_DIR, exist_ok=True)
os.makedirs(CSV_DIR, exist_ok=True)
os.makedirs(PKL_DIR, exist_ok=True)
os.makedirs(INSIGHTS_DIR, exist_ok=True)
os.makedirs(HASH_DIR, exist_ok=True)

def get_video_id(url):
    return url.split('/watch?v=')[-1]

def run_yt_dlp(video_id):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filepath = os.path.join(COMMENTS_DIR, f"{video_id}_at_{timestamp}")
    command = ["yt-dlp", "--skip-download", "--write-comments", "--no-warnings", "--output", filepath, f"https://www.youtube.com/watch?v={video_id}"]
    subprocess.run(command, check=True, text=True)



    
def get_latest_files():
    files = [f for f in os.listdir(COMMENTS_DIR) if f.endswith(".info.json")]
    latest = {}
    for f in files:
        match = re.match(r"(.+?)_at_(\d+)_\d+\.info\.json", f)
        if match:
            vid, ts_str = match.groups()
            ts = datetime.strptime(ts_str, "%Y%m%d")
            if vid not in latest or ts > latest[vid][0]:
                latest[vid] = (ts, f)
    return [f for _, f in latest.values()]

def parse_comments(json_file):
    with open(os.path.join(COMMENTS_DIR, json_file), "r", encoding="utf-8") as f:
        data = json.load(f)
    comments = data['comments']
    title = data['title']
    uploader = data['uploader_id']
    
    comment_dict = {}
    replies = defaultdict(list)
    for c in comments:
        if c.get("parent") and c["parent"] != "root":
            replies[c["parent"]].append({**c, "is_reply": True})
        else:
            comment_dict[c["id"]] = {**c, "replies": [], "is_reply": False}
    for pid, rep in replies.items():
        if pid in comment_dict:
            comment_dict[pid]["replies"] = rep
    return list(comment_dict.values()), title, uploader

def save_comments(video_id, comments):
    rows = []
    for c in comments:
        rows.append({**c, "parent_id": None})
        for r in c.get("replies", []):
            rows.append({**r, "parent_id": c["id"]})
    df = pd.DataFrame(rows)
    df.to_csv(f"{CSV_DIR}/{video_id}.csv", index=False)
    with open(f"{PKL_DIR}/{video_id}.pkl", "wb") as f:
        pickle.dump(comments, f)
    return df

def summarize_comments(api_client, comments, title, uploader_id, video_id):
    top_comments = [c['text'] for c in comments if not c['is_reply']][:max(1, int(0.05 * len(comments)))]
    comment_hash = compute_hash(top_comments)

    # Check if same hash already processed
    if get_saved_hash(video_id) == comment_hash:
        print(f"🔁 Skipping {video_id}: already summarized with same top comments.")
        return

    user_prompt = '\n'.join(top_comments)
    system_prompt = """
    The user will provide a list of YouTube comments. Please analyze all the comments together and generate a single, structured JSON object summarizing the overall qualitative dynamics.
    
    EXAMPLE INPUT:
    ["Great job! This video really opened my eyes.", "What a biased take. Shameful.", "😂😂 you're so clueless it's funny.", "Pakistan zindabad!", "Link to giveaway 👉 http://spamlink"]
    
    EXAMPLE JSON OUTPUT:
    {
      "overall_sentiment_distribution": {"positive": 1, "neutral": 1, "negative": 3},
      "dominant_emotions": ["anger", "sarcasm", "joy"],
      "toxic_comment_count": 2,
      "controversy_score": 0.75,
      "key_topics": ["bias in media", "nationalism", "truth and misinformation"],
      "frequent_bias_or_group_mentions": ["Pakistan", "India", "YouTube creators"],
      "sarcasm_detected": true,
      "languages_detected": ["English", "Urdu"],
      "spam_comment_count": 1,
      "summary": "The comment section is emotionally charged with a mix of national pride, strong criticism, and sarcasm. There's significant polarization, and a moderate amount of toxicity and spam."
    }
    """
    response = api_client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        response_format={'type': 'json_object'}
    )

    
    summary = json.loads(response.choices[0].message.content)
    summary['title'] = title
    summary['uploader_id'] = uploader_id

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    with open(f"{INSIGHTS_DIR}/{video_id}_insight1_{timestamp}.json", "w", encoding="utf-8") as f:
        json.dump(summary, f, ensure_ascii=False, indent=2)

    # Save hash
    save_hash(video_id, comment_hash)
    print(f"✅ Summarized {video_id}")

# %%
creator='@smiletojannah'

urls = fetch_latest_youtube_urls(creator, num_videos=10)
CHANNEL_URLS = pd.read_csv(f'URLs/{creator}.csv')['urls']
print(CHANNEL_URLS)
# Out:
# 0     https://www.youtube.com/watch?v=0UtHedAXIkA
# 1     https://www.youtube.com/watch?v=7tqYgfhCwb4
# 2     https://www.youtube.com/watch?v=1suta8hYDxo
# 3     https://www.youtube.com/watch?v=Ojm4C0qwhMM
# 4     https://www.youtube.com/watch?v=ItK0890LP-g
# 5     https://www.youtube.com/watch?v=dIAMoGzeut0
# 6     https://www.youtube.com/watch?v=feMoy5ioaeU
# 7     https://www.youtube.com/watch?v=Slx5ZH5NZBM
# 8     https://www.youtube.com/watch?v=aGkNouIMzFY
# 9     https://www.youtube.com/watch?v=4XaMJrS9DvY
# 10    https://www.youtube.com/watch?v=6xhUFLlG_58
# 11    https://www.youtube.com/watch?v=x84vLClrXHw
# 12    https://www.youtube.com/watch?v=YpZnd1xmP_4
# 13    https://www.youtube.com/watch?v=irE6mn-dDZk
# 14    https://www.youtube.com/watch?v=RPd-Buti7gk
# 15    https://www.youtube.com/watch?v=yn-IiJODZLc
# 16    https://www.youtube.com/watch?v=cwOPw3fBMs4
# 17    https://www.youtube.com/watch?v=JTcydTXWh6A
# 18    https://www.youtube.com/watch?v=IsqAu9bt9tI
# 19    https://www.youtube.com/watch?v=jGSm0wWxhxw
# 20    https://www.youtube.com/watch?v=lDBDgMkhZtE
# 21    https://www.youtube.com/watch?v=mXohKXpZqss
# 22    https://www.youtube.com/watch?v=4lth2pImfaE
# 23    https://www.youtube.com/watch?v=rWsg0NgJjjc
# 24    https://www.youtube.com/watch?v=TLh2DXk149Q
# 25    https://www.youtube.com/watch?v=v5sBssBzRcA
# 26    https://www.youtube.com/watch?v=bWM4zjA2rQ8
# 27    https://www.youtube.com/watch?v=-tJZffvpSYA
# 28    https://www.youtube.com/watch?v=JlkaOMU0fqA
# 29    https://www.youtube.com/watch?v=eLy6EayLUG4
# 30    https://www.youtube.com/watch?v=dXlSmWppK28
# 31    https://www.youtube.com/watch?v=spMkR6x3SyU
# 32    https://www.youtube.com/watch?v=hYxIssnzbC4
# 33    https://www.youtube.com/watch?v=O5fsrS6fGCY
# 34    https://www.youtube.com/watch?v=at1F2OmA154
# Name: urls, dtype: object

# %%
for url in CHANNEL_URLS:
    video_id = get_video_id(url)
    try:
        run_yt_dlp(video_id)
    except subprocess.CalledProcessError as e:
        print(f"Failed for {video_id}:", e.stderr)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0UtHedAXIkA
# [youtube] 0UtHedAXIkA: Downloading webpage
# [youtube] 0UtHedAXIkA: Downloading tv client config
# [youtube] 0UtHedAXIkA: Downloading tv player API JSON
# [youtube] 0UtHedAXIkA: Downloading ios player API JSON
# [youtube] 0UtHedAXIkA: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~2047 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (11/~2047)
# [youtube] Downloading comment API JSON page 2 (31/~2047)
# [youtube] Downloading comment API JSON page 3 (51/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (57/~2047)
# [youtube] Downloading comment API JSON page 4 (72/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (77/~2047)
# [youtube] Downloading comment API JSON page 5 (93/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (113/~2047)
# [youtube] Downloading comment API JSON page 6 (114/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (118/~2047)
# [youtube] Downloading comment API JSON page 7 (135/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (149/~2047)
# [youtube] Downloading comment API JSON page 8 (160/~2047)
# [youtube] Downloading comment API JSON page 9 (180/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (185/~2047)
# [youtube] Downloading comment API JSON page 10 (201/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (220/~2047)
# [youtube] Downloading comment API JSON page 11 (222/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (235/~2047)
# [youtube] Downloading comment API JSON page 12 (243/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (259/~2047)
# [youtube] Downloading comment API JSON page 13 (264/~2047)
# [youtube] Downloading comment API JSON page 14 (284/~2047)
# [youtube] Downloading comment API JSON page 15 (304/~2047)
# [youtube] Downloading comment API JSON page 16 (324/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (329/~2047)
# [youtube] Downloading comment API JSON page 17 (345/~2047)
# [youtube] Downloading comment API JSON page 18 (365/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (367/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (371/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (377/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (384/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (387/~2047)
# [youtube] Downloading comment API JSON page 19 (392/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (398/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (400/~2047)
# [youtube] Downloading comment API JSON page 20 (414/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (417/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (432/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (438/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (448/~2047)
# [youtube] Downloading comment API JSON page 21 (462/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (471/~2047)
# [youtube] Downloading comment API JSON page 22 (492/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (498/~2047)
# [youtube] Downloading comment API JSON page 23 (513/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (515/~2047)
# [youtube] Downloading comment API JSON page 24 (534/~2047)
# [youtube] Downloading comment API JSON page 25 (554/~2047)
# [youtube] Downloading comment API JSON page 26 (574/~2047)
# [youtube] Downloading comment API JSON page 27 (594/~2047)
# [youtube] Downloading comment API JSON page 28 (614/~2047)
# [youtube] Downloading comment API JSON page 29 (634/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (638/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (648/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (658/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (672/~2047)
# [youtube] Downloading comment API JSON page 30 (684/~2047)
# [youtube] Downloading comment API JSON page 31 (704/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (711/~2047)
# [youtube] Downloading comment API JSON page 32 (726/~2047)
# [youtube] Downloading comment API JSON page 33 (746/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (751/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (757/~2047)
# [youtube] Downloading comment API JSON page 34 (769/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (771/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (789/~2047)
# [youtube] Downloading comment API JSON page 35 (791/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (794/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (798/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (807/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (812/~2047)
# [youtube] Downloading comment API JSON page 36 (815/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (819/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (830/~2047)
# [youtube] Downloading comment API JSON page 37 (837/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (838/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (842/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (852/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (861/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (868/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (876/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (878/~2047)
# [youtube]     Downloading comment API JSON reply thread 7 (883/~2047)
# [youtube] Downloading comment API JSON page 38 (886/~2047)
# [youtube] Downloading comment API JSON page 39 (906/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (920/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (925/~2047)
# [youtube] Downloading comment API JSON page 40 (931/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (945/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (949/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (956/~2047)
# [youtube] Downloading comment API JSON page 41 (960/~2047)
# [youtube] Downloading comment API JSON page 42 (980/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (990/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (995/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1004/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1014/~2047)
# [youtube] Downloading comment API JSON page 43 (1020/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1029/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1034/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1046/~2047)
# [youtube] Downloading comment API JSON page 44 (1047/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1050/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1054/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1062/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1065/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1067/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1073/~2047)
# [youtube]     Downloading comment API JSON reply thread 7 (1079/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1089/~2047)
# [youtube] Downloading comment API JSON page 45 (1100/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1107/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1117/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1123/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1126/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1136/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1150/~2047)
# [youtube] Downloading comment API JSON page 46 (1155/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1162/~2047)
# [youtube] Downloading comment API JSON page 47 (1178/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1184/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1187/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1199/~2047)
# [youtube] Downloading comment API JSON page 48 (1202/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1205/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1207/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1211/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1215/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1220/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1230/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1233/~2047)
# [youtube]     Downloading comment API JSON reply thread 7 (1239/~2047)
# [youtube]     Downloading comment API JSON reply thread 8 (1242/~2047)
# [youtube] Downloading comment API JSON page 49 (1243/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1249/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1252/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1262/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1277/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1287/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1308/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1318/~2047)
# [youtube] Downloading comment API JSON page 50 (1322/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1332/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1339/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1341/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1351/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1362/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1366/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1376/~2047)
# [youtube] Downloading comment API JSON page 51 (1378/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1380/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1390/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1420/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1422/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1425/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1429/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1440/~2047)
# [youtube] Downloading comment API JSON page 52 (1444/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1452/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1462/~2047)
# [youtube]        Downloading comment replies API JSON page 2 (1512/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1523/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1533/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1536/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1540/~2047)
# [youtube] Downloading comment API JSON page 53 (1542/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1543/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1550/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1554/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1557/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1560/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1564/~2047)
# [youtube]     Downloading comment API JSON reply thread 7 (1572/~2047)
# [youtube]     Downloading comment API JSON reply thread 8 (1576/~2047)
# [youtube]     Downloading comment API JSON reply thread 9 (1582/~2047)
# [youtube]     Downloading comment API JSON reply thread 10 (1590/~2047)
# [youtube] Downloading comment API JSON page 54 (1597/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1598/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1602/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1610/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1620/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1654/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1657/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1667/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1706/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1716/~2047)
# [youtube]        Downloading comment replies API JSON page 2 (1766/~2047)
# [youtube] Downloading comment API JSON page 55 (1785/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1786/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1792/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1798/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1802/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1818/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1828/~2047)
# [youtube] Downloading comment API JSON page 56 (1832/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1836/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1846/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1859/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1867/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1869/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1879/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1909/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1915/~2047)
# [youtube] Downloading comment API JSON page 57 (1925/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (1932/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1942/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (1945/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (1949/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (1959/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (1978/~2047)
# [youtube]     Downloading comment API JSON reply thread 5 (1981/~2047)
# [youtube]     Downloading comment API JSON reply thread 6 (1994/~2047)
# [youtube] Downloading comment API JSON page 58 (1997/~2047)
# [youtube]     Downloading comment API JSON reply thread 1 (2000/~2047)
# [youtube]     Downloading comment API JSON reply thread 2 (2011/~2047)
# [youtube]     Downloading comment API JSON reply thread 3 (2019/~2047)
# [youtube]     Downloading comment API JSON reply thread 4 (2026/~2047)
# [youtube]        Downloading comment replies API JSON page 1 (2036/~2047)
# [youtube] Extracted 2047 comments
# [info] 0UtHedAXIkA: Downloading 1 format(s): 399+251
# [info] Writing video metadata as JSON to: comments_scraped/0UtHedAXIkA_at_20250519_204016.info.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7tqYgfhCwb4
# [youtube] 7tqYgfhCwb4: Downloading webpage
# [youtube] 7tqYgfhCwb4: Downloading tv client config
# [youtube] 7tqYgfhCwb4: Downloading tv player API JSON
# [youtube] 7tqYgfhCwb4: Downloading ios player API JSON
# [youtube] 7tqYgfhCwb4: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~1570 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (11/~1570)
# [youtube] Downloading comment API JSON page 2 (32/~1570)
# [youtube] Downloading comment API JSON page 3 (52/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (67/~1570)
# [youtube] Downloading comment API JSON page 4 (73/~1570)
# [youtube] Downloading comment API JSON page 5 (93/~1570)
# [youtube] Downloading comment API JSON page 6 (113/~1570)
# [youtube] Downloading comment API JSON page 7 (133/~1570)
# [youtube] Downloading comment API JSON page 8 (153/~1570)
# [youtube] Downloading comment API JSON page 9 (173/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (193/~1570)
# [youtube] Downloading comment API JSON page 10 (194/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (197/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (202/~1570)
# [youtube] Downloading comment API JSON page 11 (217/~1570)
# [youtube] Downloading comment API JSON page 12 (237/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (245/~1570)
# [youtube] Downloading comment API JSON page 13 (261/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (277/~1570)
# [youtube] Downloading comment API JSON page 14 (284/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (297/~1570)
# [youtube] Downloading comment API JSON page 15 (305/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (311/~1570)
# [youtube] Downloading comment API JSON page 16 (327/~1570)
# [youtube] Downloading comment API JSON page 17 (347/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (352/~1570)
# [youtube] Downloading comment API JSON page 18 (371/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (375/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (385/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (429/~1570)
# [youtube] Downloading comment API JSON page 19 (440/~1570)
# [youtube] Downloading comment API JSON page 20 (460/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (470/~1570)
# [youtube] Downloading comment API JSON page 21 (482/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (483/~1570)
# [youtube] Downloading comment API JSON page 22 (503/~1570)
# [youtube] Downloading comment API JSON page 23 (523/~1570)
# [youtube] Downloading comment API JSON page 24 (543/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (557/~1570)
# [youtube] Downloading comment API JSON page 25 (564/~1570)
# [youtube] Downloading comment API JSON page 26 (584/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (594/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (598/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (604/~1570)
# [youtube] Downloading comment API JSON page 27 (609/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (610/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (621/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (635/~1570)
# [youtube] Downloading comment API JSON page 28 (640/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (647/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (650/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (655/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (669/~1570)
# [youtube] Downloading comment API JSON page 29 (672/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (689/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (695/~1570)
# [youtube] Downloading comment API JSON page 30 (696/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (700/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (710/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (726/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (736/~1570)
# [youtube] Downloading comment API JSON page 31 (748/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (751/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (762/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (780/~1570)
# [youtube] Downloading comment API JSON page 32 (783/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (784/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (797/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (800/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (810/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (816/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (826/~1570)
# [youtube]        Downloading comment replies API JSON page 2 (876/~1570)
# [youtube]     Downloading comment API JSON reply thread 5 (886/~1570)
# [youtube]     Downloading comment API JSON reply thread 6 (888/~1570)
# [youtube] Downloading comment API JSON page 33 (893/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (895/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (909/~1570)
# [youtube] Downloading comment API JSON page 34 (916/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (928/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (930/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (937/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (941/~1570)
# [youtube] Downloading comment API JSON page 35 (943/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (944/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (947/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (951/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (953/~1570)
# [youtube]     Downloading comment API JSON reply thread 5 (955/~1570)
# [youtube]     Downloading comment API JSON reply thread 6 (959/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (969/~1570)
# [youtube]     Downloading comment API JSON reply thread 7 (1011/~1570)
# [youtube]     Downloading comment API JSON reply thread 8 (1018/~1570)
# [youtube]     Downloading comment API JSON reply thread 9 (1021/~1570)
# [youtube] Downloading comment API JSON page 36 (1028/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1029/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (1033/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (1044/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (1054/~1570)
# [youtube]     Downloading comment API JSON reply thread 5 (1056/~1570)
# [youtube]     Downloading comment API JSON reply thread 6 (1060/~1570)
# [youtube]     Downloading comment API JSON reply thread 7 (1068/~1570)
# [youtube]     Downloading comment API JSON reply thread 8 (1072/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1082/~1570)
# [youtube]        Downloading comment replies API JSON page 2 (1132/~1570)
# [youtube]     Downloading comment API JSON reply thread 9 (1149/~1570)
# [youtube]     Downloading comment API JSON reply thread 10 (1151/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1161/~1570)
# [youtube] Downloading comment API JSON page 37 (1201/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1202/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (1206/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (1220/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (1230/~1570)
# [youtube] Downloading comment API JSON page 38 (1232/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1233/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (1237/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (1240/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (1248/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1258/~1570)
# [youtube] Downloading comment API JSON page 39 (1277/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1280/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (1287/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1297/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (1314/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (1316/~1570)
# [youtube]     Downloading comment API JSON reply thread 5 (1322/~1570)
# [youtube]     Downloading comment API JSON reply thread 6 (1327/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1337/~1570)
# [youtube]     Downloading comment API JSON reply thread 7 (1344/~1570)
# [youtube]     Downloading comment API JSON reply thread 8 (1348/~1570)
# [youtube]     Downloading comment API JSON reply thread 9 (1354/~1570)
# [youtube] Downloading comment API JSON page 40 (1357/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1364/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (1366/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1376/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (1379/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (1381/~1570)
# [youtube]     Downloading comment API JSON reply thread 5 (1388/~1570)
# [youtube]     Downloading comment API JSON reply thread 6 (1391/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1401/~1570)
# [youtube]     Downloading comment API JSON reply thread 7 (1412/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1422/~1570)
# [youtube]     Downloading comment API JSON reply thread 8 (1432/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1442/~1570)
# [youtube] Downloading comment API JSON page 41 (1443/~1570)
# [youtube]     Downloading comment API JSON reply thread 1 (1444/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1454/~1570)
# [youtube]     Downloading comment API JSON reply thread 2 (1462/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1472/~1570)
# [youtube]     Downloading comment API JSON reply thread 3 (1480/~1570)
# [youtube]     Downloading comment API JSON reply thread 4 (1486/~1570)
# [youtube]     Downloading comment API JSON reply thread 5 (1490/~1570)
# [youtube]        Downloading comment replies API JSON page 1 (1500/~1570)
# [youtube]        Downloading comment replies API JSON page 2 (1550/~1570)
# [youtube]     Downloading comment API JSON reply thread 6 (1560/~1570)
# [youtube]     Downloading comment API JSON reply thread 7 (1562/~1570)
# [youtube]     Downloading comment API JSON reply thread 8 (1565/~1570)
# [youtube] Extracted 1570 comments
# [info] 7tqYgfhCwb4: Downloading 1 format(s): 399+251
# [info] Writing video metadata as JSON to: comments_scraped/7tqYgfhCwb4_at_20250519_204101.info.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1suta8hYDxo
# [youtube] 1suta8hYDxo: Downloading webpage
# [youtube] 1suta8hYDxo: Downloading tv client config
# [youtube] 1suta8hYDxo: Downloading tv player API JSON
# [youtube] 1suta8hYDxo: Downloading ios player API JSON
# [youtube] 1suta8hYDxo: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~1323 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (1/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (11/~1323)
# [youtube] Downloading comment API JSON page 2 (32/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (51/~1323)
# [youtube] Downloading comment API JSON page 3 (53/~1323)
# [youtube] Downloading comment API JSON page 4 (73/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (74/~1323)
# [youtube] Downloading comment API JSON page 5 (94/~1323)
# [youtube] Downloading comment API JSON page 6 (114/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (115/~1323)
# [youtube] Downloading comment API JSON page 7 (135/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (151/~1323)
# [youtube] Downloading comment API JSON page 8 (156/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (162/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (171/~1323)
# [youtube] Downloading comment API JSON page 9 (182/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (195/~1323)
# [youtube] Downloading comment API JSON page 10 (203/~1323)
# [youtube] Downloading comment API JSON page 11 (223/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (235/~1323)
# [youtube] Downloading comment API JSON page 12 (244/~1323)
# [youtube] Downloading comment API JSON page 13 (264/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (266/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (284/~1323)
# [youtube] Downloading comment API JSON page 14 (286/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (290/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (303/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (308/~1323)
# [youtube] Downloading comment API JSON page 15 (312/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (313/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (320/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (323/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (326/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (334/~1323)
# [youtube]     Downloading comment API JSON reply thread 6 (337/~1323)
# [youtube] Downloading comment API JSON page 16 (339/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (341/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (351/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (356/~1323)
# [youtube] Downloading comment API JSON page 17 (367/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (368/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (376/~1323)
# [youtube] Downloading comment API JSON page 18 (389/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (390/~1323)
# [youtube] Downloading comment API JSON page 19 (411/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (419/~1323)
# [youtube] Downloading comment API JSON page 20 (432/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (434/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (437/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (440/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (452/~1323)
# [youtube] Downloading comment API JSON page 21 (461/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (466/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (469/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (475/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (487/~1323)
# [youtube] Downloading comment API JSON page 22 (492/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (503/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (511/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (514/~1323)
# [youtube] Downloading comment API JSON page 23 (516/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (517/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (529/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (543/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (553/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (560/~1323)
# [youtube] Downloading comment API JSON page 24 (566/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (574/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (584/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (589/~1323)
# [youtube] Downloading comment API JSON page 25 (599/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (607/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (611/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (622/~1323)
# [youtube] Downloading comment API JSON page 26 (625/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (628/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (636/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (639/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (644/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (649/~1323)
# [youtube] Downloading comment API JSON page 27 (658/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (660/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (666/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (679/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (686/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (692/~1323)
# [youtube] Downloading comment API JSON page 28 (697/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (700/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (704/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (710/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (720/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (730/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (732/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (742/~1323)
# [youtube] Downloading comment API JSON page 29 (754/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (757/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (762/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (770/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (777/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (787/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (793/~1323)
# [youtube]     Downloading comment API JSON reply thread 6 (803/~1323)
# [youtube] Downloading comment API JSON page 30 (811/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (816/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (823/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (833/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (837/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (840/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (847/~1323)
# [youtube] Downloading comment API JSON page 31 (853/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (854/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (858/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (860/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (862/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (869/~1323)
# [youtube]     Downloading comment API JSON reply thread 6 (879/~1323)
# [youtube]     Downloading comment API JSON reply thread 7 (883/~1323)
# [youtube]     Downloading comment API JSON reply thread 8 (892/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (902/~1323)
# [youtube]     Downloading comment API JSON reply thread 9 (939/~1323)
# [youtube]     Downloading comment API JSON reply thread 10 (943/~1323)
# [youtube]     Downloading comment API JSON reply thread 11 (950/~1323)
# [youtube] Downloading comment API JSON page 32 (952/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (954/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (964/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (991/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (1001/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (1006/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (1016/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (1026/~1323)
# [youtube]     Downloading comment API JSON reply thread 6 (1036/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (1046/~1323)
# [youtube]     Downloading comment API JSON reply thread 7 (1050/~1323)
# [youtube] Downloading comment API JSON page 33 (1060/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (1066/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (1076/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (1100/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (1102/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (1104/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (1114/~1323)
# [youtube]        Downloading comment replies API JSON page 2 (1164/~1323)
# [youtube]        Downloading comment replies API JSON page 3 (1214/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (1218/~1323)
# [youtube]     Downloading comment API JSON reply thread 6 (1220/~1323)
# [youtube]     Downloading comment API JSON reply thread 7 (1229/~1323)
# [youtube] Downloading comment API JSON page 34 (1236/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (1242/~1323)
# [youtube]     Downloading comment API JSON reply thread 2 (1247/~1323)
# [youtube]     Downloading comment API JSON reply thread 3 (1254/~1323)
# [youtube]     Downloading comment API JSON reply thread 4 (1263/~1323)
# [youtube]     Downloading comment API JSON reply thread 5 (1270/~1323)
# [youtube]     Downloading comment API JSON reply thread 6 (1279/~1323)
# [youtube]     Downloading comment API JSON reply thread 7 (1282/~1323)
# [youtube]     Downloading comment API JSON reply thread 8 (1286/~1323)
# [youtube]        Downloading comment replies API JSON page 1 (1296/~1323)
# [youtube]     Downloading comment API JSON reply thread 9 (1318/~1323)
# [youtube] Downloading comment API JSON page 35 (1320/~1323)
# [youtube]     Downloading comment API JSON reply thread 1 (1322/~1323)
# [youtube] Extracted 1323 comments
# [info] 1suta8hYDxo: Downloading 1 format(s): 399+251
# [info] Writing video metadata as JSON to: comments_scraped/1suta8hYDxo_at_20250519_204133.info.json
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ojm4C0qwhMM
# [youtube] Ojm4C0qwhMM: Downloading webpage
# [youtube] Ojm4C0qwhMM: Downloading tv client config
# [youtube] Ojm4C0qwhMM: Downloading tv player API JSON
# [youtube] Ojm4C0qwhMM: Downloading ios player API JSON
# [youtube] Ojm4C0qwhMM: Downloading m3u8 information
# [youtube] Downloading comment section API JSON
# [youtube] Downloading ~1801 comments
# [youtube] Sorting comments by newest first
# [youtube] Downloading comment API JSON page 1 (0/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (1/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (11/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (38/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (43/~1801)
# [youtube] Downloading comment API JSON page 2 (46/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (51/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (54/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (56/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (61/~1801)
# [youtube]     Downloading comment API JSON reply thread 5 (68/~1801)
# [youtube]     Downloading comment API JSON reply thread 6 (74/~1801)
# [youtube] Downloading comment API JSON page 3 (78/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (79/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (81/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (87/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (90/~1801)
# [youtube]     Downloading comment API JSON reply thread 5 (95/~1801)
# [youtube]     Downloading comment API JSON reply thread 6 (97/~1801)
# [youtube]     Downloading comment API JSON reply thread 7 (99/~1801)
# [youtube]     Downloading comment API JSON reply thread 8 (101/~1801)
# [youtube]     Downloading comment API JSON reply thread 9 (106/~1801)
# [youtube] Downloading comment API JSON page 4 (110/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (116/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (126/~1801)
# [youtube] Downloading comment API JSON page 5 (132/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (149/~1801)
# [youtube] Downloading comment API JSON page 6 (154/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (162/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (164/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (169/~1801)
# [youtube] Downloading comment API JSON page 7 (180/~1801)
# [youtube] Downloading comment API JSON page 8 (200/~1801)
# [youtube] Downloading comment API JSON page 9 (220/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (229/~1801)
# [youtube] Downloading comment API JSON page 10 (243/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (248/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (253/~1801)
# [youtube] Downloading comment API JSON page 11 (265/~1801)
# [youtube] Downloading comment API JSON page 12 (285/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (294/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (304/~1801)
# [youtube] Downloading comment API JSON page 13 (321/~1801)
# [youtube] Downloading comment API JSON page 14 (341/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (347/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (357/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (365/~1801)
# [youtube] Downloading comment API JSON page 15 (374/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (381/~1801)
# [youtube] Downloading comment API JSON page 16 (397/~1801)
# [youtube] Downloading comment API JSON page 17 (417/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (419/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (427/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (432/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (442/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (455/~1801)
# [youtube] Downloading comment API JSON page 18 (459/~1801)
# [youtube] Downloading comment API JSON page 19 (479/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (499/~1801)
# [youtube] Downloading comment API JSON page 20 (500/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (508/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (510/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (517/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (526/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (536/~1801)
# [youtube] Downloading comment API JSON page 21 (540/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (542/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (547/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (560/~1801)
# [youtube] Downloading comment API JSON page 22 (563/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (568/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (576/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (585/~1801)
# [youtube] Downloading comment API JSON page 23 (587/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (590/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (600/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (622/~1801)
# [youtube] Downloading comment API JSON page 24 (627/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (633/~1801)
# [youtube] Downloading comment API JSON page 25 (649/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (656/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (666/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (692/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (694/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (697/~1801)
# [youtube] Downloading comment API JSON page 26 (699/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (700/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (702/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (704/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (718/~1801)
# [youtube] Downloading comment API JSON page 27 (727/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (744/~1801)
# [youtube]        Downloading comment replies API JSON page 1 (754/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (783/~1801)
# [youtube] Downloading comment API JSON page 28 (786/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (789/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (792/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (795/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (798/~1801)
# [youtube]     Downloading comment API JSON reply thread 5 (810/~1801)
# [youtube]     Downloading comment API JSON reply thread 6 (812/~1801)
# [youtube] Downloading comment API JSON page 29 (822/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (825/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (835/~1801)
# [youtube] Downloading comment API JSON page 30 (844/~1801)
# [youtube] Downloading comment API JSON page 31 (864/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (867/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (869/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (874/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (876/~1801)
# [youtube]     Downloading comment API JSON reply thread 5 (888/~1801)
# [youtube]     Downloading comment API JSON reply thread 6 (894/~1801)
# [youtube] Downloading comment API JSON page 32 (897/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (907/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (917/~1801)
# [youtube] Downloading comment API JSON page 33 (920/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (923/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (936/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (945/~1801)
# [youtube] Downloading comment API JSON page 34 (950/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (960/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (968/~1801)
# [youtube] Downloading comment API JSON page 35 (980/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (985/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (989/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (994/~1801)
# [youtube]     Downloading comment API JSON reply thread 4 (998/~1801)
# [youtube]     Downloading comment API JSON reply thread 5 (1002/~1801)
# [youtube]     Downloading comment API JSON reply thread 6 (1007/~1801)
# [youtube] Downloading comment API JSON page 36 (1010/~1801)
# [youtube]     Downloading comment API JSON reply thread 1 (1022/~1801)
# [youtube]     Downloading comment API JSON reply thread 2 (1033/~1801)
# [youtube]     Downloading comment API JSON reply thread 3 (1039/~1801)
# [youtube] Downloading comment API JSON page 37 (1040/~1801)
# ...
# [youtube] Downloading comment API JSON page 68 (1652/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1661/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (1670/~5976)
# [youtube] Downloading comment API JSON page 69 (1674/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1675/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (1685/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (1724/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (1736/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (1746/~5976)
# [youtube] Downloading comment API JSON page 70 (1750/~5976)
# [youtube] Downloading comment API JSON page 71 (1770/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1780/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (1785/~5976)
# [youtube] Downloading comment API JSON page 72 (1793/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1797/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (1802/~5976)
# [youtube] Downloading comment API JSON page 73 (1815/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1816/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (1820/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (1823/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (1825/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (1835/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (1880/~5976)
# [youtube] Downloading comment API JSON page 74 (1887/~5976)
# [youtube] Downloading comment API JSON page 75 (1907/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1916/~5976)
# [youtube] Downloading comment API JSON page 76 (1928/~5976)
# [youtube] Downloading comment API JSON page 77 (1948/~5976)
# [youtube] Downloading comment API JSON page 78 (1968/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (1971/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (1978/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (1993/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (1997/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (1999/~5976)
# [youtube]     Downloading comment API JSON reply thread 6 (2007/~5976)
# [youtube] Downloading comment API JSON page 79 (2008/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2015/~5976)
# [youtube] Downloading comment API JSON page 80 (2031/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2033/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2035/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2037/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (2053/~5976)
# [youtube] Downloading comment API JSON page 81 (2056/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2065/~5976)
# [youtube] Downloading comment API JSON page 82 (2077/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2090/~5976)
# [youtube] Downloading comment API JSON page 83 (2098/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2102/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2106/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2117/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (2120/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (2122/~5976)
# [youtube] Downloading comment API JSON page 84 (2124/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2127/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2131/~5976)
# [youtube] Downloading comment API JSON page 85 (2151/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2163/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2173/~5976)
# [youtube] Downloading comment API JSON page 86 (2186/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2188/~5976)
# [youtube] Downloading comment API JSON page 87 (2207/~5976)
# [youtube] Downloading comment API JSON page 88 (2227/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2228/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2234/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2239/~5976)
# [youtube] Downloading comment API JSON page 89 (2250/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2259/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2269/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2296/~5976)
# [youtube] Downloading comment API JSON page 90 (2306/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2313/~5976)
# [youtube] Downloading comment API JSON page 91 (2327/~5976)
# [youtube] Downloading comment API JSON page 92 (2347/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2354/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2361/~5976)
# [youtube] Downloading comment API JSON page 93 (2369/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2373/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2375/~5976)
# [youtube] Downloading comment API JSON page 94 (2392/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2412/~5976)
# [youtube] Downloading comment API JSON page 95 (2413/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2422/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2430/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2436/~5976)
# [youtube] Downloading comment API JSON page 96 (2438/~5976)
# [youtube] Downloading comment API JSON page 97 (2458/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2459/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2461/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2463/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (2473/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (2477/~5976)
# [youtube]     Downloading comment API JSON reply thread 6 (2481/~5976)
# [youtube]     Downloading comment API JSON reply thread 7 (2486/~5976)
# [youtube] Downloading comment API JSON page 98 (2488/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2504/~5976)
# [youtube] Downloading comment API JSON page 99 (2509/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2513/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2524/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2532/~5976)
# [youtube] Downloading comment API JSON page 100 (2534/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2542/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2547/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2557/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2567/~5976)
# [youtube] Downloading comment API JSON page 101 (2568/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2586/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2589/~5976)
# [youtube] Downloading comment API JSON page 102 (2590/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2595/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2599/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (2608/~5976)
# [youtube] Downloading comment API JSON page 103 (2616/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2622/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2633/~5976)
# [youtube] Downloading comment API JSON page 104 (2641/~5976)
# [youtube] Downloading comment API JSON page 105 (2661/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2677/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2687/~5976)
# [youtube] Downloading comment API JSON page 106 (2691/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2696/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2706/~5976)
# [youtube]        Downloading comment replies API JSON page 2 (2756/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2807/~5976)
# [youtube] Downloading comment API JSON page 107 (2819/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2824/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2834/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2853/~5976)
# [youtube] Downloading comment API JSON page 108 (2858/~5976)
# [youtube] Downloading comment API JSON page 109 (2878/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2891/~5976)
# [youtube] Downloading comment API JSON page 110 (2902/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2907/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2917/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2955/~5976)
# [youtube] Downloading comment API JSON page 111 (2963/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (2968/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (2984/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (2994/~5976)
# [youtube] Downloading comment API JSON page 112 (3028/~5976)
# [youtube] Downloading comment API JSON page 113 (3048/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3066/~5976)
# [youtube] Downloading comment API JSON page 114 (3073/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3078/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3088/~5976)
# [youtube] Downloading comment API JSON page 115 (3105/~5976)
# [youtube] Downloading comment API JSON page 116 (3125/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3135/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3139/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3141/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (3144/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (3150/~5976)
# [youtube] Downloading comment API JSON page 117 (3152/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3154/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3156/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3158/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (3165/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (3168/~5976)
# [youtube] Downloading comment API JSON page 118 (3178/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3183/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3193/~5976)
# [youtube] Downloading comment API JSON page 119 (3211/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3225/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3235/~5976)
# [youtube] Downloading comment API JSON page 120 (3243/~5976)
# [youtube] Downloading comment API JSON page 121 (3263/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3264/~5976)
# [youtube] Downloading comment API JSON page 122 (3284/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3294/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3304/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3328/~5976)
# [youtube] Downloading comment API JSON page 123 (3337/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3350/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3360/~5976)
# [youtube] Downloading comment API JSON page 124 (3379/~5976)
# [youtube] Downloading comment API JSON page 125 (3399/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3408/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3418/~5976)
# [youtube] Downloading comment API JSON page 126 (3438/~5976)
# [youtube] Downloading comment API JSON page 127 (3458/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3463/~5976)
# [youtube] Downloading comment API JSON page 128 (3479/~5976)
# [youtube] Downloading comment API JSON page 129 (3499/~5976)
# [youtube] Downloading comment API JSON page 130 (3519/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3527/~5976)
# [youtube] Downloading comment API JSON page 131 (3540/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3546/~5976)
# [youtube] Downloading comment API JSON page 132 (3561/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3565/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3575/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3579/~5976)
# [youtube] Downloading comment API JSON page 133 (3598/~5976)
# [youtube] Downloading comment API JSON page 134 (3618/~5976)
# [youtube] Downloading comment API JSON page 135 (3638/~5976)
# [youtube] Downloading comment API JSON page 136 (3658/~5976)
# [youtube] Downloading comment API JSON page 137 (3678/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3696/~5976)
# [youtube] Downloading comment API JSON page 138 (3699/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3702/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3706/~5976)
# [youtube] Downloading comment API JSON page 139 (3723/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3724/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3726/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3731/~5976)
# [youtube] Downloading comment API JSON page 140 (3746/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3757/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3767/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3776/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3781/~5976)
# [youtube] Downloading comment API JSON page 141 (3787/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3802/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3809/~5976)
# [youtube] Downloading comment API JSON page 142 (3810/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3820/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3824/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3826/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (3832/~5976)
# [youtube]     Downloading comment API JSON reply thread 5 (3835/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (3845/~5976)
# [youtube] Downloading comment API JSON page 143 (3876/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3879/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3900/~5976)
# [youtube] Downloading comment API JSON page 144 (3904/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3918/~5976)
# [youtube] Downloading comment API JSON page 145 (3926/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3929/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3939/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3943/~5976)
# [youtube]     Downloading comment API JSON reply thread 4 (3945/~5976)
# [youtube] Downloading comment API JSON page 146 (3954/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3965/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3972/~5976)
# [youtube] Downloading comment API JSON page 147 (3976/~5976)
# [youtube]     Downloading comment API JSON reply thread 1 (3981/~5976)
# [youtube]     Downloading comment API JSON reply thread 2 (3987/~5976)
# [youtube]     Downloading comment API JSON reply thread 3 (3992/~5976)
# [youtube]        Downloading comment replies API JSON page 1 (4002/~5976)

# %%
client = OpenAI(api_key=API_KEY, base_url="https://api.deepseek.com")

for json_file in get_latest_files():
    match = re.match(r"(.+?)_at_\d+_\d+\.info\.json", json_file)
    if not match:
        continue
    video_id = match.group(1)
    comments, title, uploader = parse_comments(json_file)
    df = save_comments(video_id, comments)
    summarize_comments(client, comments, title, uploader, video_id)
    print(f"Completed {video_id}\n{'*'*10}")

# %%
import subprocess
import json
import pandas as pd
import time
import os

num_urls = 20
creators = [
    #'@smiletojannah',
    #'@thedeshbhakt',
    #'@MuslimSkeptic',
    #'@TheDiaryOfACEO'
    '@BenAI92',
    '@VanessaWingårdh'
    
]

output_path = 'URLs/url_channel_id.csv'
os.makedirs('URLs', exist_ok=True)

# Load existing data if the file exists
if os.path.exists(output_path):
    existing_df = pd.read_csv(output_path)
    existing_ids = set(existing_df['id'].astype(str))
else:
    existing_df = pd.DataFrame(columns=['creator_id', 'id', 'url', 'timestamp'])
    existing_ids = set()

# Prepare new data
new_data = {
    'creator_id': [],
    'id': [],
    'url': [],
    'timestamp': []
}

for creator in creators:
    channel_url = f"https://www.youtube.com/{creator}"  # or channel ID/URL

    # Run yt-dlp to fetch JSON metadata
    result = subprocess.run(
        ["yt-dlp", "--dump-json", "--flat-playlist", "--playlist-end", str(num_urls), channel_url],
        capture_output=True, text=True
    )

    # Parse each line
    video_entries = [json.loads(line) for line in result.stdout.strip().split('\n')]

    now = str(time.time())
    for entry in video_entries:
        video_id = entry['id']
        if video_id not in existing_ids:
            new_data['creator_id'].append(creator)
            new_data['id'].append(video_id)
            new_data['url'].append(f"https://www.youtube.com/watch?v={video_id}")
            new_data['timestamp'].append(now)
            existing_ids.add(video_id)  # Mark as seen

# Save if new data exists
if new_data['id']:
    new_df = pd.DataFrame(new_data)
    combined_df = pd.concat([existing_df, new_df], ignore_index=True)
    combined_df.to_csv(output_path, index=False)
    print(f"✅ Added {len(new_df)} new videos.")
else:
    print("🔁 No new videos to add.")
# Out:
# 🔁 No new videos to add.

# %%
'''
00GetVidsForChannel
01CExtractComments
02AAnalyzeComments
03ASummarizeByCreator
'''
# Out:
# '\n00GetVidsForChannel\n01CExtractComments\n02AAnalyzeComments\n03ASummarizeByCreator\n'

# %%
result
# Out:
# CompletedProcess(args=['yt-dlp', '--dump-json', '--flat-playlist', '--playlist-end', '20', 'https://www.youtube.com/@VanessaWingårdh'], returncode=0, stdout='{"_type": "url", "ie_key": "Youtube", "id": "QECHcQyQhN0", "url": "https://www.youtube.com/watch?v=QECHcQyQhN0", "title": "How Your Tax Dollars Built Palantir\'s Global Surveillance Empire", "description": "From a startup founded by Peter Thiel and funded by the CIA to a $370 billion tech giant, Palantir has quietly become one of the most powerful companies in the world.\\n\\nSources: \\nPalantir S-1...", "duration": 1280.0, "channel_id": null, "channel": null, "channel_url": null, "uploader": null, "uploader_id": null, "uploader_url": null, "thumbnails": [{"url": "https://i.ytimg.com/vi/QECHcQyQhN0/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBi_d1fhGI9IKYpQbeurcXQo-P7tQ", "height": 94, "width": 168}, {"url": "https://i.ytimg.com/vi/QECHcQyQhN0/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBmx62Pkm96pJi-rlKRIFaJownEYg", "height": 110, "width": 196}, {"url": "https://i.ytimg.com/vi/QECHcQyQhN0/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAr_sjd_T6gznof9Pk8pGb8otjLPA", "height": 138, "width": 246}, {"url": "https://i.ytimg.com/vi/QECHcQyQhN0/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCP1XBg5sQtTqtU36TEmffOyWeFWg", "height": 188, "width": 336}], "timestamp": null, "release_timestamp": null, "availability": null, "view_count": 41923, "live_status": null, "channel_is_verified": null, "__x_forwarded_for_ip": null, "webpage_url": "https://www.youtube.com/watch?v=QECHcQyQhN0", "original_url": "https://www.youtube.com/watch?v=QECHcQyQhN0", "webpage_url_basename": "watch", "webpage_url_domain": "youtube.com", "extractor": "youtube", "extractor_key": "Youtube", "playlist_count": null, "playlist": "Vanessa Wing\\u00e5rdh - Videos", "playlist_id": "UC2Bm4qXVUx9Md-hmHz3WuXw", "playlist_title": "Vanessa Wing\\u00e5rdh - Videos", "playlist_uploader": "Vanessa Wing\\u00e5rdh", "playlist_uploader_id": "@VanessaWing\\u00e5rdh", "playlist_channel": "Vanessa Wing\\u00e5rdh", "playlist_channel_id": "UC2Bm4qXVUx9Md-hmHz3WuXw", "playlist_webpage_url": "https://www.youtube.com/@VanessaWing\\u00e5rdh/videos", "n_entries": 20, "playlist_index": 1, "__last_playlist_index": 20, "playlist_autonumber": 1, "epoch": 1757256840, "duration_string": "21:20", "release_year": null, "_version": {"version": "2025.04.30", "current_git_head": null, "release_git_head": "505b400795af557bdcfd9d4fa7e9133b26ef431c", "repository": "yt-dlp/yt-dlp"}}\n{"_type": "url", "ie_key": "Youtube", "id": "hJ2tqs_vksc", "url": "https://www.youtube.com/watch?v=hJ2tqs_vksc", "title": "The Real Reason Your Power Bill Doubled (It\'s Not Inflation)", "description": "Electricity bills are skyrocketing and water reserves are dwindling, yet Big Tech giants like OpenAI, Meta, and Amazon are thriving. They\\u2019ve secured billions in tax breaks while you foot...", "duration": 992.0, "channel_id": null, "channel": null, "channel_url": null, "uploader": null, "uploader_id": null, "uploader_url": null, "thumbnails": [{"url": "https://i.ytimg.com/vi/hJ2tqs_vksc/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC-P_GTyokY2qhcr9pjUnnlg5AbKg", "height": 94, "width": 168}, {"url": "https://i.ytimg.com/vi/hJ2tqs_vksc/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCKFVBl8cUdF65aamtciVqClvUItQ", "height": 110, "width": 196}, {"url": "https://i.ytimg.com/vi/hJ2tqs_vksc/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDJhpScqH868q2Xo-j7arsPnwV_Fw", "height": 138, "width": 246}, {"url": "https://i.ytimg.com/vi/hJ2tqs_vksc/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA9LvRkMD_13eZe2dW2kszSxV8Mfg", "height": 188, "width": 336}], "timestamp": null, "release_timestamp": null, "availability": null, "view_count": 506825, "live_status": null, ...

# %%
import os
import re
import json
import time
import pickle
import pandas as pd
from openai import OpenAI


API_KEY = 'sk-9d500b16988f4ac1b963d92fdddcca2a'

# %%
def to_process(video_id, reference_file_path):
    if not os.path.exists(reference_file_path):
        return True
    df = pd.read_csv(reference_file_path)
    #print(df['id'].astype(str).values)
    return video_id not in df['id'].astype(str).values

# %%
def summarize_comments(api_client, comments, title, uploader_id, video_id):
    top_comments = [c['text'] for c in comments if not c['is_reply']][:max(1, int(0.5 * len(comments)))]
    
    print(f'number of comments to be considered={len(top_comments)}')
    user_prompt = '\n'.join(top_comments)
    system_prompt = """
    The user will provide a list of YouTube comments. Please analyze all the comments together and generate a single, structured JSON object summarizing the overall qualitative dynamics.
    
    EXAMPLE INPUT:
    ["Great job! This video really opened my eyes.", "What a biased take. Shameful.", "😂😂 you're so clueless it's funny.", "Pakistan zindabad!", "Link to giveaway 👉 http://spamlink"]
    
    EXAMPLE JSON OUTPUT:
    {
      "overall_sentiment_distribution": {"positive": 1, "neutral": 1, "negative": 3},
      "dominant_emotions": ["anger", "sarcasm", "joy"],
      "toxic_comment_count": 2,
      "controversy_score": 0.75,
      "key_topics": ["bias in media", "nationalism", "truth and misinformation"],
      "frequent_bias_or_group_mentions": ["Pakistan", "India", "YouTube creators"],
      "sarcasm_detected": true,
      "languages_detected": ["English", "Urdu"],
      "spam_comment_count": 1,
      "summary": "The comment section is emotionally charged with a mix of national pride, strong criticism, and sarcasm. There's significant polarization, and a moderate amount of toxicity and spam."
    }
    """
    response = api_client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        response_format={'type': 'json_object'}
    )

    
    summary = json.loads(response.choices[0].message.content)
    summary['title'] = title
    summary['uploader_id'] = uploader_id

    return summary

# %%
PROCESSED_COMMENTS_DIR = 'processed_comments'
df_comments=pd.read_csv(f'{PROCESSED_COMMENTS_DIR}/comments.csv')

df_comments['comments'] = df_comments['comments'].apply(json.loads)



ANALYZED_COMMENTS_DIR = 'analyzed_comments'
analyzed_comments_file_path = f'{ANALYZED_COMMENTS_DIR}/analyzed_comments.csv'


client = OpenAI(api_key=API_KEY, base_url="https://api.deepseek.com")
data_res = []
for index, row in df_comments.iterrows():
    try:
        print(row)
        if not to_process(row['id'],analyzed_comments_file_path):
            print(f"⏩ Skipping already processed video ID: {row['id']}")
            continue
        print(f"Analyzing video ID: {row['id']}")
        analysis=summarize_comments(client, row['comments'], row['title'] ,row['creator_id'], row['id'])
        data_res.append({
                'creator_id': row['creator_id'],
                'id': row['id'],
                'title': row['title'],
                'timestamp': str(time.time()),
                'analysis': json.dumps(analysis)
            })
        # Append to CSV immediately to avoid reprocessing on crash
        df = pd.DataFrame(data_res)
        if os.path.exists(analyzed_comments_file_path):
            df.to_csv(analyzed_comments_file_path, mode='a', index=False, header=False)
        else:
            df.to_csv(analyzed_comments_file_path, index=False)
        data_res.clear()        
    except Exception as e:
        print(f"❌ Failed to process video ID: {row['id']}")
        print(e)
# Out:
# creator_id                                     @VanessaWingårdh
# id                                                  QECHcQyQhN0
# title         How Your Tax Dollars Built Palantir's Global S...
# timestamp                                     1757444475.679061
# comments      [{'id': 'UgyWHlrJBtNYbPkhOiV4AaABAg', 'parent'...
# Name: 0, dtype: object
# Analyzing video ID: QECHcQyQhN0
# number of comments to be considered=36
# creator_id                                     @VanessaWingårdh
# id                                                  hJ2tqs_vksc
# title         The Real Reason Your Power Bill Doubled (It's ...
# timestamp                                     1757444480.772202
# comments      [{'id': 'UgwkfCoILKo_AVMbVGt4AaABAg', 'parent'...
# Name: 1, dtype: object
# Analyzing video ID: hJ2tqs_vksc
# number of comments to be considered=47
# creator_id                                     @VanessaWingårdh
# id                                                  cyMWig4AR4k
# title         AI Price Gouging: Corporate Greed Is Out of Co...
# timestamp                                      1757444485.75364
# comments      [{'id': 'UgwcflV2ByXT0ErKUpl4AaABAg', 'parent'...
# Name: 2, dtype: object
# Analyzing video ID: cyMWig4AR4k
# number of comments to be considered=49
# creator_id                                     @VanessaWingårdh
# id                                                  J5ZmLvy_Jfg
# title         The Internet is Dying: AI, Bots, and The End o...
# timestamp                                     1757444490.907639
# comments      [{'id': 'UgxImoud8kRx0zeVfv94AaABAg', 'parent'...
# Name: 3, dtype: object
# Analyzing video ID: J5ZmLvy_Jfg
# number of comments to be considered=1
# creator_id                                     @VanessaWingårdh
# id                                                  KJFouW0Xh2E
# title         Real or AI? The Internet Is Now Impossible to ...
# timestamp                                     1757444495.897706
# comments      [{'id': 'Ugxr5tZc3jH1zoi96XV4AaABAg', 'parent'...
# Name: 4, dtype: object
# Analyzing video ID: KJFouW0Xh2E
# number of comments to be considered=49
# creator_id                                     @VanessaWingårdh
# id                                                  1LL34dmB-bU
# title                             The ChatGPT CEO's Web of Lies
# timestamp                                     1757444501.160645
# comments      [{'id': 'Ugzl3qw3nl7lGQCuM-x4AaABAg', 'parent'...
# Name: 5, dtype: object
# Analyzing video ID: 1LL34dmB-bU
# number of comments to be considered=50
# creator_id                                     @VanessaWingårdh
# id                                                  6aVRQDKJ9Dg
# title             ChatGPT Brain Rot Is Real (And Getting Worse)
# timestamp                                     1757444506.817166
# comments      [{'id': 'Ugz7JjT5irQ0MD3HJwh4AaABAg', 'parent'...
# Name: 6, dtype: object
# Analyzing video ID: 6aVRQDKJ9Dg
# number of comments to be considered=45
# creator_id                                     @VanessaWingårdh
# id                                                  qfK6H714moc
# title                  ChatGPT Religion: The Disturbing AI Cult
# timestamp                                     1757444512.006272
# comments      [{'id': 'UgxPS0-h5e4ypTMjmeJ4AaABAg', 'parent'...
# Name: 7, dtype: object
# Analyzing video ID: qfK6H714moc
# number of comments to be considered=1
# creator_id                                     @VanessaWingårdh
# id                                                  6yR5isyYhTM
# title             Man Proposes to AI Chatbot… Is this Cheating?
# timestamp                                     1757444517.096588
# comments      [{'id': 'UgzqBXb1aoAFua7TM-d4AaABAg', 'parent'...
# Name: 8, dtype: object
# Analyzing video ID: 6yR5isyYhTM
# number of comments to be considered=47
# creator_id                                     @VanessaWingårdh
# id                                                  JYpLWjbMGzc
# title            Meta AI Made Private Chats Public and It’s Bad
# timestamp                                     1757444522.712123
# comments      [{'id': 'UgygUlHNnaUCNLmG6Ax4AaABAg', 'parent'...
# Name: 9, dtype: object
# Analyzing video ID: JYpLWjbMGzc
# number of comments to be considered=43
# creator_id                                     @VanessaWingårdh
# id                                                  7J1lxTwvzZE
# title         The Dating App Scam: Why They Don't Want You t...
# timestamp                                     1757444527.422482
# comments      [{'id': 'UgxCp_YBa4_iI29Gzp94AaABAg', 'parent'...
# Name: 10, dtype: object
# Analyzing video ID: 7J1lxTwvzZE
# number of comments to be considered=49
# creator_id                                     @VanessaWingårdh
# id                                                  W-EzAu_xpM8
# title         AI CEO’s Job Replacement Panic: What Research ...
# timestamp                                     1757444532.194402
# comments      [{'id': 'UgyvefHX5DnG703tGrl4AaABAg', 'parent'...
# Name: 11, dtype: object
# Analyzing video ID: W-EzAu_xpM8
# number of comments to be considered=46
# creator_id                                     @VanessaWingårdh
# id                                                  Zpjyd1S6rvo
# title         AI vs Teachers: Tech CEOs Promise a Fix but iP...
# timestamp                                     1757444537.150387
# comments      [{'id': 'UgzHig90uGG45CvLO0Z4AaABAg', 'parent'...
# Name: 12, dtype: object
# Analyzing video ID: Zpjyd1S6rvo
# number of comments to be considered=49
# creator_id                                     @VanessaWingårdh
# id                                                  LcQGXC1f-8s
# title         AI is Ruining Job Interviews: Profits over People
# timestamp                                     1757444542.610549
# comments      [{'id': 'UgxQ6g_ghbJOQpShWNJ4AaABAg', 'parent'...
# Name: 13, dtype: object
# Analyzing video ID: LcQGXC1f-8s
# number of comments to be considered=48
# creator_id                                     @VanessaWingårdh
# id                                                  7ARTSXfLIaU
# title                    Subscription Scam: We’ve Been Tricked!
# timestamp                                     1757444547.279341
# comments      [{'id': 'UgwjS_z4e2firCTsGhx4AaABAg', 'parent'...
# Name: 14, dtype: object
# Analyzing video ID: 7ARTSXfLIaU
# number of comments to be considered=48
# creator_id                                     @VanessaWingårdh
# id                                                  T6BKIt2QKQM
# title                   AI-First Companies: Profits over People
# timestamp                                     1757444552.056999
# comments      [{'id': 'Ugz67rlMbMgu0e8lGMZ4AaABAg', 'parent'...
# Name: 15, dtype: object
# Analyzing video ID: T6BKIt2QKQM
# number of comments to be considered=40
# creator_id                                     @VanessaWingårdh
# id                                                  een8H8TIDF4
# title         Retro Tech Revival: Trading AI for Nostalgia &...
# timestamp                                     1757444556.975076
# comments      [{'id': 'Ugwf5IosRA1xwsvLBSN4AaABAg', 'parent'...
# Name: 16, dtype: object
# Analyzing video ID: een8H8TIDF4
# number of comments to be considered=41
# creator_id                                     @VanessaWingårdh
# id                                                  PUV5Wjmh_CM
# title                          Boring Games are Making Millions
# timestamp                                     1757444562.170704
# comments      [{'id': 'Ugy_NeOm9JQie0lxANx4AaABAg', 'parent'...
# Name: 17, dtype: object
# Analyzing video ID: PUV5Wjmh_CM
# number of comments to be considered=32
# creator_id                                     @VanessaWingårdh
# id                                                  CqSA-nTpkb0
# title         How Instagram Stories hack your brain's reward...
# timestamp                                      1757444566.32155
# comments      [{'id': 'UgzylCkQp-hIlrqup7Z4AaABAg', 'parent'...
# Name: 18, dtype: object
# Analyzing video ID: CqSA-nTpkb0
# number of comments to be considered=25
# creator_id                                     @VanessaWingårdh
# id                                                  QQ71Y9cOemM
# title         How a Software Engineer Stays Consistent | My ...
# timestamp                                       1757444570.2766
# comments      [{'id': 'UgxSVaT3iSuK4jthI3J4AaABAg', 'parent'...
# Name: 19, dtype: object
# Analyzing video ID: QQ71Y9cOemM
# number of comments to be considered=24
# creator_id                                     @VanessaWingårdh
# id                                                  wSxxlXC9nsM
# title         Why Swedish Nature Laws are Like Open Source #...
# timestamp                                     1757444574.509767
# comments      [{'id': 'UgyU7WkIj3lBFriB4ft4AaABAg', 'parent'...
# Name: 20, dtype: object
# Analyzing video ID: wSxxlXC9nsM
# number of comments to be considered=11

# %%
df.tail()
# Out:
#          creator_id           id  \
# 0  @VanessaWingårdh  wSxxlXC9nsM
#
#                                                title          timestamp  \
# 0  Why Swedish Nature Laws are Like Open Source #...  1757445901.987659
#
#                                             analysis
# 0  {"overall_sentiment_distribution": {"positive"...

# %%
df
# Out:
#          creator_id           id  \
# 0  @VanessaWingårdh  wSxxlXC9nsM
#
#                                                title          timestamp  \
# 0  Why Swedish Nature Laws are Like Open Source #...  1757445901.987659
#
#                                             analysis
# 0  {"overall_sentiment_distribution": {"positive"...
